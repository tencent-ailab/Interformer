# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
df = pd.read_csv('/opt/home/revoli/eva/Interformer/result/core_timetest_round0_ensemble.csv')
df['no_clash'] = df['vdwdistance_inter_min_1_post_refinement'] > -1.3
#
# print('*' * 100)
df.corr(numeric_only=True)
# Out:
#                                             pose_rank  \
# pose_rank                                1.000000e+00
# vdwdistance_inter_min_1_post_refinement -4.713456e-03
# energy                                   2.503219e-01
# rmsd                                     2.586123e-01
# Year                                    -1.925660e-15
# pIC50                                   -5.536772e-02
# pred_pIC50                              -2.630089e-01
# pred_pose                               -2.000012e-01
# no_clash                                -5.085450e-02
#
#                                          vdwdistance_inter_min_1_post_refinement  \
# pose_rank                                                              -0.004713
# vdwdistance_inter_min_1_post_refinement                                 1.000000
# energy                                                                  0.178826
# rmsd                                                                   -0.018996
# ...

# %%
crystal = df[df['pose_rank'] == 20]
crystal.corr(numeric_only=True)
# Out:
#                                          pose_rank  \
# pose_rank                                      NaN
# vdwdistance_inter_min_1_post_refinement        NaN
# energy                                         NaN
# rmsd                                           NaN
# Year                                           NaN
# pIC50                                          NaN
# pred_pIC50                                     NaN
# pred_pose                                      NaN
#
#                                          vdwdistance_inter_min_1_post_refinement  \
# pose_rank                                                                    NaN
# vdwdistance_inter_min_1_post_refinement                                 1.000000
# energy                                                                  0.005540
# rmsd                                                                         NaN
# Year                                                                   -0.102196
# ...
